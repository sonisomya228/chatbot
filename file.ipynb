# %%
from langchain_core.tools import tool

@tool
def division(a: int,b: int)-> int:
    """Divide 2 numbers"""
    return a%b

result=division.invoke({"a":4,"b":8})
print(result)
print(division.name)
print(division.description)
print(division.args)
# Out:
# 4
# division
# Divide 2 numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
from typing import Annotated,List

@tool
def multiply_by_max(
    a:Annotated[int, "A value"],
    b: Annotated[List[int], "List of ints over which to take maximum"]
)->int:
    """Multiply a by the maximum of b"""
    return a*max(b)

print(multiply_by_max.args)
result=multiply_by_max.invoke({"a":7,"b":{3,5,6,7,2,1,9}})
print(result)
print(multiply_by_max.description)
# Out:
# {'a': {'description': 'A value', 'title': 'A', 'type': 'integer'}, 'b': {'description': 'List of ints over which to take maximum', 'items': {'type': 'integer'}, 'title': 'B', 'type': 'array'}}
# 63
# Multiply a by the maximum of b

# %%
from langchain_core.tools import StructuredTool

def multiply(a:int, b:int)->int:
    """Multiply two numbers"""
    return a*b

async def amultiply(a:int, b:int)->int:
    """Multiply two numbers"""
    return a*b

calculator=StructuredTool.from_function(func=multiply,coroutine=amultiply)
print(calculator.invoke({"a":2, "b":3}))
print(await calculator.ainvoke({"a":2,"b":5}))
# Out:
# 6
# 10

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

api_wrapper = WikipediaAPIWrapper(
    top_k_result=5,
    doc_content_chars_max=500
)

tool = WikipediaQueryRun(api_wrapper=api_wrapper)

print(tool.invoke({"query": "langchain"}))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from langchain_community.tools import WikipediaQueryRun
#       2 from langchain_community.utilities import WikipediaAPIWrapper
#       3
#       4 api_wrapper = WikipediaAPIWrapper(
#
# ModuleNotFoundError: No module named 'langchain_community'

# %%
import sys

# !{sys.executable} -m pip install -U langchain-community wikipedia
# Out:
# d:\chatbot\.venv\Scripts\python.exe: No module named pip

# %%
import sys

# !{sys.executable} -m pip install -U langchain-community wikipedia
# Out:
# d:\chatbot\.venv\Scripts\python.exe: No module named pip

# %%
import sys
print(sys.version)
# Out:
# 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
import os
import sys

scripts_dir = os.path.dirname(sys.executable)
print(scripts_dir)
print(os.listdir(scripts_dir))
# Out:
# d:\chatbot\.venv\Scripts
# ['activate', 'activate.bat', 'activate.csh', 'activate.fish', 'activate.nu', 'activate.ps1', 'activate_this.py', 'deactivate.bat', 'debugpy-adapter.exe', 'debugpy.exe', 'distro.exe', 'dotenv.exe', 'f2py.exe', 'httpx.exe', 'idna.exe', 'ipython.exe', 'ipython3.exe', 'jsondiff', 'jsonpatch', 'jsonpointer', 'jsonschema.exe', 'jupyter-kernel.exe', 'jupyter-kernelspec.exe', 'jupyter-migrate.exe', 'jupyter-run.exe', 'jupyter-troubleshoot.exe', 'jupyter.exe', 'normalizer.exe', 'numpy-config.exe', 'pydoc.bat', 'pygmentize.exe', 'python.exe', 'pythonw.exe', 'streamlit.exe', 'tqdm.exe', 'uvicorn.exe', 'watchmedo.exe', 'websockets.exe']
